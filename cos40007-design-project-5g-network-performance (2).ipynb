# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

files = []

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        file_dir = os.path.join(dirname, filename)
        files.append(file_dir)
        print(f"{os.path.join(dirname, filename)} added to files array")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data5g/2022-07-08-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/clean_data.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-06-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-14-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo07-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-22-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo05-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-05-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-04-garbo04-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-20-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo10-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-08-garbo09-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-13-garbo08-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-18-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-15-garbo11-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-19-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-11-garbo03-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo02-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-07-garbo01-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-21-garbo06-combined-kml.csv added to files array
# /kaggle/input/data5g/2022-07-12-garbo09-combined-kml.csv added to files array

# %%
print(len(files))
# Out:
# 137

# %%
#Data Ingestion & Cleaning
#Filter out Invalid GPS Points & Parse timestamps

cleaned_dataframes = []

for file in files:
    data5G = pd.read_csv(file, low_memory=False) #Read csv file and remove warnings
    #GPS Points 
    data5G = data5G[(data5G['latitude'] != 99999) & (data5G['longitude'] != 99999)] #99,999 is used for invalid detection

    #Parse timestamps 
    data5G['time'] = pd.to_datetime(data5G['time'], unit='s', errors='coerce') #Removes invalid values (abc) and converts numeric values into time and date
    data5G = data5G.dropna(subset=['time']) #Removes rows with invalid timestamps

    cleaned_dataframes.append(data5G)

master_data5G = pd.concat(cleaned_dataframes, ignore_index=True)

master_data5G.to_csv('/kaggle/working/master_data5G.csv', index=False) #Convert to a master csv 

print("Data cleaning completed and saved as'master_data5G.csv'")
# Out:
# Data cleaning completed and saved as'master_data5G.csv'
